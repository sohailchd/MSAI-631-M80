# %%
import sys
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import sklearn

# --- 1. Check and print library versions ---
print("--- Checking Library Versions ---")
print(f"Python version: {sys.version}")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print(f"Scikit-learn version: {sklearn.__version__}")
print("-" * 30)

# --- 2. Test basic functionality and plotting ---
print("\n--- Generating a Test Plot ---")
try:
    # Generate some sample data using NumPy
    x = np.linspace(0, 2 * np.pi, 100)
    y = np.sin(x)

    # Create a plot using Matplotlib
    plt.figure(figsize=(8, 4))
    plt.plot(x, y, label='sin(x)')
    plt.title("Jupyter Setup Test Plot")
    plt.xlabel("x-axis")
    plt.ylabel("y-axis")
    plt.grid(True)
    plt.legend()
    plt.show()

    print("\nTest plot generated successfully!")

except Exception as e:
    print(f"\nAn error occurred during plotting: {e}")


# --- 3. Final Confirmation ---
print("\nJupyter Notebook setup test complete.")
print("If you can see the library versions and a plot above, your environment is likely configured correctly for basic data science tasks.")
# Out:
# --- Checking Library Versions ---
# Python version: 3.11.5 (main, Sep 11 2023, 08:31:25) [Clang 14.0.6 ]
# NumPy version: 2.3.1
# Pandas version: 2.3.2
# Matplotlib version: 3.10.5
# Scikit-learn version: 1.7.1
# ------------------------------
#
# --- Generating a Test Plot ---
# Test plot generated successfully!
#
# Jupyter Notebook setup test complete.
# If you can see the library versions and a plot above, your environment is likely configured correctly for basic data science tasks.

# %%
# !pip install flask
# Out:
# Requirement already satisfied: flask in /opt/anaconda3/envs/msai631/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: blinker>=1.9.0 in /opt/anaconda3/envs/msai631/lib/python3.11/site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /opt/anaconda3/envs/msai631/lib/python3.11/site-packages (from flask) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /opt/anaconda3/envs/msai631/lib/python3.11/site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/anaconda3/envs/msai631/lib/python3.11/site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/anaconda3/envs/msai631/lib/python3.11/site-packages (from flask) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /opt/anaconda3/envs/msai631/lib/python3.11/site-packages (from flask) (3.1.3)

# %%
from flask import Flask, request, jsonify, render_template
import logging

app = Flask(__name__)
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)


@app.route('/')
def hello_world():
    logger.info
    return render_template('index.html')

# %%
import os
import platform
from IPython import get_ipython

def is_notebook() -> bool:
    try:
        print(os.name)
        print(platform.system())
        shell = get_ipython().__class__.__name__
        if shell == 'ZMQInteractiveShell':
            return True   # Jupyter notebook or qtconsole
        elif shell == 'TerminalInteractiveShell':
            return False  # Terminal running IPython
        else:
            return False  # Other type (?)
    except NameError:
        return False      # Probably standard Python interpreter

# %%
if is_notebook():
    print("Running in a Jupyter environment")
    app.run()
